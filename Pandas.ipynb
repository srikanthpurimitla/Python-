# %%
import pandas as pd

# %% [markdown]
# <h2>a)create a small dataframe</h2>

# %%
df_england={'Name':['Kane','Steling','Saka','Magure'],
            'Age':[27,26,29,28]}
dfn=pd.DataFrame(df_england)

# %%
df_italy={'Name':['Immobile','','',''],
         'Age':[31,23,43,23]}
dfm=pd.DataFrame(df_italy)

# %%
dfn.set_index(['Age'])
# Out:
#         Name
# Age
# 27      Kane
# 26   Steling
# 29      Saka
# 28    Magure

# %% [markdown]
# <h2>concantenation<h2/>

# %%
frames=([dfn,dfm])
both_teams=pd.concat(frames)
both_teams
# Out:
#        Name  Age
# 0      Kane   27
# 1   Steling   26
# 2      Saka   29
# 3    Magure   28
# 0  Immobile   31
# 1             23
# 2             43
# 3             23

# %% [markdown]
# <h2>Setting conditions</h2>

# %%
both_teams[both_teams['Age']>=30]
# Out:
#        Name  Age
# 0  Immobile   31
# 2             43

# %%
both_teams[both_teams['Name'].str.startswith('K')]
# Out:
#    Name  Age
# 0  Kane   27

# %% [markdown]
# <h2>Adding new column </h2>

# %%
club=['Tottenham','Mancity','Arsena','Manut']
df_england['Associated Clubs']=club
df_england
# Out:
# {'Name': ['Kane', 'Steling', 'Saka', 'Magure'],
#  'Age': [27, 26, 29, 28],
#  'Associated Clubs': ['Tottenham', 'Mancity', 'Arsena', 'Manut']}

# %%
dfn.loc[1:2]
# Out:
#       Name  Age
# 1  Steling   26
# 2     Saka   29

# %%
dfn.loc[2]
# Out:
# Name    Saka
# Age       29
# Name: 2, dtype: object

# %% [markdown]
# <h2>reading different file</h2>

# %% [markdown]
# <h3>Zip file </h3>

# %%
from zipfile import ZipFile

# %%
file='Z:/SEM6/ML/Datasets/Ex-2 files.zip'
with ZipFile (file,'r') as zip:
    zip.printdir()
    zip.extractall()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-5421bf61b182> in <module>()
#       1 file='Z:/SEM6/ML/Datasets/Ex-2 files.zip'
# ----> 2 with ZipFile (file,'r') as zip:
#       3     zip.printdir()
#       4     zip.extractall()
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1088             while True:
#    1089                 try:
# -> 1090                     self.fp = io.open(file, filemode)
#    1091                 except OSError:
#    1092                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Z:/SEM6/ML/Datasets/Ex-2 files.zip'

# %% [markdown]
# <h2>b)Reading text file </h2>

# %%
with open('Z:\SEM6\ML\Datasets\pokemon_data.txt','r') as f:
    print(f.read())
# Out:
# #	Name	Type 1	Type 2	HP	Attack	Defense	Sp. Atk	Sp. Def	Speed	Generation	Legendary
# 1	Bulbasaur	Grass	Poison	45	49	49	65	65	45	1	FALSE
# 2	Ivysaur	Grass	Poison	60	62	63	80	80	60	1	FALSE
# 3	Venusaur	Grass	Poison	80	82	83	100	100	80	1	FALSE
# 3	VenusaurMega Venusaur	Grass	Poison	80	100	123	122	120	80	1	FALSE
# 4	Charmander	Fire		39	52	43	60	50	65	1	FALSE
# 5	Charmeleon	Fire		58	64	58	80	65	80	1	FALSE
# 6	Charizard	Fire	Flying	78	84	78	109	85	100	1	FALSE
# 6	CharizardMega Charizard X	Fire	Dragon	78	130	111	130	85	100	1	FALSE
# 6	CharizardMega Charizard Y	Fire	Flying	78	104	78	159	115	100	1	FALSE
# 7	Squirtle	Water		44	48	65	50	64	43	1	FALSE
# 8	Wartortle	Water		59	63	80	65	80	58	1	FALSE
# 9	Blastoise	Water		79	83	100	85	105	78	1	FALSE
# 9	BlastoiseMega Blastoise	Water		79	103	120	135	115	78	1	FALSE
# 10	Caterpie	Bug		45	30	35	20	20	45	1	FALSE
# 11	Metapod	Bug		50	20	55	25	25	30	1	FALSE
# 12	Butterfree	Bug	Flying	60	45	50	90	80	70	1	FALSE
# ...

# %%
with open('Z:\SEM6\ML\Datasets\pokemon_data.txt','r') as f:
    print(f.read(10))
# Out:
# #	Name	Typ

# %%
with open('Z:\SEM6\ML\Datasets\pokemon_data.txt','r') as f:
    print(f.readline())
# Out:
# #	Name	Type 1	Type 2	HP	Attack	Defense	Sp. Atk	Sp. Def	Speed	Generation	Legendary

# %%
with open('Z:\SEM6\ML\Datasets\pokemon_data.txt','r') as f:
    print(f.readlines())
# Out:
# ['#\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary\n', '1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t65\t45\t1\tFALSE\n', '2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\t60\t1\tFALSE\n', '3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t100\t80\t1\tFALSE\n', '3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t100\t123\t122\t120\t80\t1\tFALSE\n', '4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\t1\tFALSE\n', '5\tCharmeleon\tFire\t\t58\t64\t58\t80\t65\t80\t1\tFALSE\n', '6\tCharizard\tFire\tFlying\t78\t84\t78\t109\t85\t100\t1\tFALSE\n', '6\tCharizardMega Charizard X\tFire\tDragon\t78\t130\t111\t130\t85\t100\t1\tFALSE\n', '6\tCharizardMega Charizard Y\tFire\tFlying\t78\t104\t78\t159\t115\t100\t1\tFALSE\n', '7\tSquirtle\tWater\t\t44\t48\t65\t50\t64\t43\t1\tFALSE\n', '8\tWartortle\tWater\t\t59\t63\t80\t65\t80\t58\t1\tFALSE\n', '9\tBlastoise\tWater\t\t79\t83\t100\t85\t105\t78\t1\tFALSE\n', '9\tBlastoiseMega Blastoise\tWater\t\t79\t103\t120\t135\t115\t78\t1\tF
# ...

# %%
pok_df = pd.read_table('Z:\SEM6\ML\Datasets\pokemon_data.txt')
pok_df
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass  Poison   45      49       49
# 1      2                    Ivysaur     Grass  Poison   60      62       63
# 2      3                   Venusaur     Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4      4                 Charmander      Fire     NaN   39      52       43
# 5      5                 Charmeleon      Fire     NaN   58      64       58
# 6      6                  Charizard      Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 9      7                   Squirtle     Water     NaN   44      48       65
# 10     8                  Wartortle     Water     NaN   59      63       80
# ...

# %% [markdown]
# <h3>c)CSV file</h3>

# %%
titanic_df = pd.read_csv('Z:\\SEM6\\ML\\Datasets\\titanic.csv')
titanic_df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# 5           0       3                                    Mr. James Moran
# 6           0       1                             Mr. Timothy J McCarthy
# 7           0       3                      Master. Gosta Leonard Palsson
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10          1       3                     Miss. Marguerite Rut Sandstrom
# 11          1       1                            Miss. Elizabeth Bonnell
# ...

# %% [markdown]
# <h3>d)Excel file </h3>

# %%
store_df = pd.read_excel('Z:\\SEM6\\ML\\Datasets\\Superstore.xlsx')
store_df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 8          9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 9         10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11        12  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 12        13  CA-2017-114412 2017-04-15 2017-04-20  Standard Class
# ...

# %% [markdown]
# <h3>e)JSON files</h3>

# %%
post_df = pd.read_json('Z:\\SEM6\\ML\\Datasets\\posts.json')
post_df
# Out:
#                                                  body   id  \
# 0   quia et suscipit\nsuscipit recusandae consequu...    1
# 1   est rerum tempore vitae\nsequi sint nihil repr...    2
# 2   et iusto sed quo iure\nvoluptatem occaecati om...    3
# 3   ullam et saepe reiciendis voluptatem adipisci\...    4
# 4   repudiandae veniam quaerat sunt sed\nalias aut...    5
# 5   ut aspernatur corporis harum nihil quis provid...    6
# 6   dolore placeat quibusdam ea quo vitae\nmagni q...    7
# 7   dignissimos aperiam dolorem qui eum\nfacilis q...    8
# 8   consectetur animi nesciunt iure dolore\nenim q...    9
# 9   quo et expedita modi cum officia vel magni\ndo...   10
# 10  delectus reiciendis molestiae occaecati non mi...   11
# 11  itaque id aut magnam\npraesentium quia et ea o...   12
# 12  aut dicta possimus sint mollitia voluptas comm...   13
# 13  fuga et accusamus dolorum perferendis illo vol...   14
# 14  reprehenderit quos placeat\nvelit minima offic...   15
# ...
